# %% [markdown]
# # Read IFS Data
#
# ## Make sure you have gribberish **not gribberish spire** installed.
#
# ```bash
# pip uninstall gribberish-spire
# pip install gribberish
# ```

# %% [markdown]
# ## Imports

# %%
import xarray as xr

# %% [markdown]
# ## Read the data with xarray

# %%
ds = xr.open_dataset("sample-data/ecmwf.t12z.pgrb.0p125.f000",
                     engine="gribberish")
ds
# Out:
# /Users/maxwellgrover/git_repos/gribberish/python/gribberish/gribberish_backend.py:50: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   return xr.Dataset(
# <xarray.Dataset> Size: 896MB
# Dimensions:        (time: 1, latitude: 1441, longitude: 2880, isobar_2: 3,
#                     isobar_0: 4, isobar_3: 4, isobar_1: 3)
# Coordinates:
#   * time           (time) datetime64[ns] 8B 2025-11-24T12:00:00
#   * isobar_0       (isobar_0) float64 32B 700.0 850.0 925.0 1e+03
#   * isobar_1       (isobar_1) float64 24B 800.0 900.0 950.0
# ...

# %% [markdown]
# ## Plot 2m temperature

# %%
ds.t2m.plot()
